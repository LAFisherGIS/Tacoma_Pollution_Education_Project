# %%
#gwr approach based on https://deepnote.com/@carlos-mendez/PYTHON-GWR-and-MGWR-71dd8ba9-a3ea-4d28-9b20-41cc8a282b7a
#however, this tutorial seems to no longer exist
import pandas as pd
pd.set_option('display.max_columns', None)

import matplotlib.pyplot as plt
from matplotlib.ticker import FormatStrFormatter
import matplotlib as mpl
mpl.rcParams['figure.dpi'] = 72

import geopandas as gpd

import libpysal as ps

import esda

from mgwr.gwr import GWR, MGWR
from mgwr.sel_bw import Sel_BW
from mgwr.utils import shift_colormap, truncate_colormap

# %matplotlib inline

# %%
def altReg(file, longitude, latitude, band, topic, demographic, year, disadvantage, treq, output, c):
    # Performs a GWR on the math or reading scores of students in 2014 or 2015 based on pollution exposure estimates
    # and American Community Survey attested demographic characteristics including
    # size, adult education levels, and career makeups.
    
    # Requires that the data follow a specific labelling guide, which will have been noted in comments above.
    '''File is the file path. Longitude and Latitude are the XY coordinates of the centroid of each polygon. band is a 
    bandwidth, which I had to manually input due to issues with the library failing to calculate reasonable bandwidths. 
    Topic is either math or read, used to select which grades will be analyzed as the dependant variable. Demographic 
    can be 'overall', 'white', 'black', 'native', 'asian', 'pacific', or 'multi', and is used in selecting the dependent 
    and independent variables. Year is the year to be computed, and is used in selecting the dependent and 
    independent variables. treq is the desired t-value for statistical significance.
    
    Disadvantage is 'A' 'B' or 'C' depending on which is being tested
    
    Output is the location to which you want your plots and other outputs saved. Set to 'no' if you do not wish to have
    anything saved.'''
    
    #income, population, and percentage working in the services were cut due to causing errors with 2015 elementary and all
    #middle school analyses

    
    gdf  = gpd.read_file(file)
    
    #this section automatically constructs all of the strings that will be used to select the data to be used
    
    if topic == 'read':
        dep = 'r'
    elif topic == 'math':
        dep = 'm'
    else: 
        print('invalid topic, please enter read or math')
        return
    
    if year == '2014':
        end = '14'
    elif year == '2015':
        end = '15'
    else:
        print('invalid year, please enter 2014 or 2015')
        return

    if demographic == 'overall':
        ent = '_over'
        demo = 'Over'
    elif demographic == 'white':
        ent = '_whi'
        demo = 'White'
    elif demographic == 'black':
        ent = '_bla'
        demo = 'Black'
    elif demographic == 'native':
        ent = '_nati'
        demo = 'Nativ'
    elif demographic == 'asian':
        ent = '_asi'
        demo = 'Asian'
    elif demographic == 'pacific':
        ent = '_paci'
        demo = 'Pacif'
    elif demographic == 'multi':
        ent = '_mul'
        demo = 'Multi'
    else:
        print('Invalid demographic.')
        return
        
    dependent = dep + end + ent
    
    pollution = demo + 'Pol' + end
    
    income = demo + 'Inc' + end

    disad = demo + 'Dis' + disadvantage + end

    independent = [pollution, disad]
    
    y = gdf[dependent].values.reshape((-1,1)) # reshape is needed to have column array
    y.shape

    X = gdf[independent].values
    X.shape

    u = gdf[longitude]
    v = gdf[latitude]
    coords = list(zip(u,v))
    
    gwr_results = GWR(coords, y, X, bw=band).fit()
        
    suma = gwr_results.summary()
    
    suma
    
    sumadest = output + disadvantage + dependent + '_suma.txt'
    
    #doesn't work properly because they didn't make .summary give a string, please save manually
    #https://www.pythontutorial.net/python-basics/python-create-text-file/
    with open(sumadest, 'w') as f:
        f.write(str(suma))
    
    print('Mean R2 =', gwr_results.R2)
    print('AIC =', gwr_results.aic)
    print('AICc =', gwr_results.aicc)
    
    r2 = 'gwr' + dependent + 'R2'
    
    gdf[r2] = gwr_results.localR2
    
    location = output + disadvantage + dependent + '.png'
    
    fig, ax = plt.subplots(figsize=(6, 6))
    
    #sometimes, there aren't enough unique r^2s for a multi-class GWR
    
    gdf.plot(column=r2, cmap = 'coolwarm', linewidth=0.01, scheme = 'FisherJenks', k=c, legend=True, legend_kwds={'bbox_to_anchor':(1.10, 0.96)},  ax=ax)
    ax.set_title(r2, fontsize=12)
    ax.axis("off")
    plt.savefig(location ,dpi=150, bbox_inches='tight')
    plt.show()
    
    inter = 'gwr' + dependent + '_intercept'
    
    gdf[inter] = gwr_results.params[:,0]
    gdf[pollution] = gwr_results.params[:,1]
    gdf[disad] = gwr_results.params[:,2]
    '''gdf[business] = gwr_results.params[:,2]
    gdf[science] = gwr_results.params[:,3]
    gdf[healthcare] = gwr_results.params[:,4]
    gdf[educationAndLegal] = gwr_results.params[:,5]
    gdf[salesAndOffice] = gwr_results.params[:,6]
    gdf[extraction] = gwr_results.params[:,7]
    gdf[logistics] = gwr_results.params[:,8]'''

    gwr_math_filtered_t = gwr_results.filter_tvals(alpha = treq)
    gwr_math_filtered_tc = gwr_results.filter_tvals()

    t = pd.DataFrame(gwr_math_filtered_t)
    tc = pd.DataFrame(gwr_math_filtered_tc)
    
    t
    tc
    
    tdest = output + dependent + '_t.csv'
    tcdest = output + dependent + '_tc.csv'
    
    t.to_csv(tdest)
    tc.to_csv(tcdest)
    
    LCC, VIF, CN, VDP = gwr_results.local_collinearity()

    vif = pd.DataFrame(VIF)
    roundedVif =pd.DataFrame(VIF).describe().round(2)
    cn = pd.DataFrame(CN)
    
    vif
    roundedVif
    cn
    
    vifdest = output + dependent + '_vif.csv'
    rvifdest = output + dependent + '_rvif.csv'
    cndest = output + dependent + '_cn.csv'

    vif.to_csv(vifdest)
    roundedVif.to_csv(rvifdest)
    cn.to_csv(cndest)
    
    cnf = demo + 'CN' + end
    
    gdf[cnf] = CN

# %%
target = 'C'

# %%
altReg('other_data\polygons_points\Schools_with_Data\elem_fin_dis.shp', 'POINT_X', 
              'POINT_Y', 35, 'read', 'overall', '2014', target, 0.3, 'gwrresults/alt/elem_dis', 5)
# Out:
# ===========================================================================
# Model type                                                         Gaussian
# Number of observations:                                                  35
# Number of covariates:                                                     3
#
# Global Regression Results
# ---------------------------------------------------------------------------
# Residual sum of squares:                                           1349.325
# Log-likelihood:                                                    -113.573
# AIC:                                                                233.146
# AICc:                                                               236.479
# BIC:                                                               1235.553
# R2:                                                                   0.631
# Adj. R2:                                                              0.608
#
# Variable                              Est.         SE  t(Est/SE)    p-value
# ------------------------------- ---------- ---------- ---------- ----------
# X0                                  12.427      5.249      2.368      0.018
# X1                                  -0.200      0.104     -1.918      0.055
# X2                                  -1.207      0.207     -5.839      0.000
#
# Geographically Weighted Regression (GWR) Results
# ---------------------------------------------------------------------------
# Spatial kernel:                                           Adaptive bisquare
# Bandwidth used:                                                      35.000
#
# Diagnostic information
# ---------------------------------------------------------------------------
# Residual sum of squares:                                           1163.685
# Effective number of parameters (trace(S)):                            5.015
# Degree of freedom (n - trace(S)):                                    29.985
# Sigma estimate:                                                       6.230
# Log-likelihood:                                                    -110.983
# AIC:                                                                233.995
# AICc:                                                               237.010
# BIC:                                                                243.350
# R2:                                                                   0.682
# Adjusted R2:                                                          0.627
# Adj. alpha (95%):                                                     0.030
# Adj. critical t value (95%):                                          2.266
#
# Summary Statistics For GWR Parameter Estimates
# ---------------------------------------------------------------------------
# Variable                   Mean        STD        Min     Median        Max
# -------------------- ---------- ---------- ---------- ---------- ----------
# X0                       16.490      5.154      6.837     17.776     23.511
# X1                       -0.253      0.080     -0.353     -0.285     -0.105
# X2                       -1.266      0.074     -1.377     -1.263     -1.095
# ===========================================================================
#
# Mean R2 = 0.6817140181105974
# AIC = 233.99486306050565
# AICc = 237.010003689173

# %%
altReg('other_data\polygons_points\Schools_with_Data\elem_fin_dis.shp', 'POINT_X', 
              'POINT_Y', 35, 'math', 'overall', '2014', target, 0.3, 'gwrresults/alt/elem_dis', 5)
# Out:
# ===========================================================================
# Model type                                                         Gaussian
# Number of observations:                                                  35
# Number of covariates:                                                     3
#
# Global Regression Results
# ---------------------------------------------------------------------------
# Residual sum of squares:                                           3345.229
# Log-likelihood:                                                    -129.462
# AIC:                                                                264.924
# AICc:                                                               268.257
# BIC:                                                               3231.458
# R2:                                                                   0.517
# Adj. R2:                                                              0.486
#
# Variable                              Est.         SE  t(Est/SE)    p-value
# ------------------------------- ---------- ---------- ---------- ----------
# X0                                  14.179      8.265      1.715      0.086
# X1                                  -0.329      0.164     -2.002      0.045
# X2                                  -1.395      0.326     -4.286      0.000
#
# Geographically Weighted Regression (GWR) Results
# ---------------------------------------------------------------------------
# Spatial kernel:                                           Adaptive bisquare
# Bandwidth used:                                                      35.000
#
# Diagnostic information
# ---------------------------------------------------------------------------
# Residual sum of squares:                                           3020.615
# Effective number of parameters (trace(S)):                            5.015
# Degree of freedom (n - trace(S)):                                    29.985
# Sigma estimate:                                                      10.037
# Log-likelihood:                                                    -127.676
# AIC:                                                                267.380
# AICc:                                                               270.395
# BIC:                                                                276.735
# R2:                                                                   0.563
# Adjusted R2:                                                          0.488
# Adj. alpha (95%):                                                     0.030
# Adj. critical t value (95%):                                          2.266
#
# Summary Statistics For GWR Parameter Estimates
# ---------------------------------------------------------------------------
# Variable                   Mean        STD        Min     Median        Max
# -------------------- ---------- ---------- ---------- ---------- ----------
# X0                       17.248      6.213      7.468     17.189     27.019
# X1                       -0.354      0.146     -0.565     -0.383     -0.121
# X2                       -1.489      0.109     -1.658     -1.468     -1.308
# ===========================================================================
#
# Mean R2 = 0.5634279886234779
# AIC = 267.38025886106556
# AICc = 270.3953994897329

# %%
altReg('other_data\polygons_points\Schools_with_Data\elem_fin_dis.shp', 'POINT_X', 
              'POINT_Y', 35, 'read', 'overall', '2015', target, 0.3, 'gwrresults/alt/elem_dis', 5)
# Out:
# ===========================================================================
# Model type                                                         Gaussian
# Number of observations:                                                  35
# Number of covariates:                                                     3
#
# Global Regression Results
# ---------------------------------------------------------------------------
# Residual sum of squares:                                           2444.846
# Log-likelihood:                                                    -123.975
# AIC:                                                                253.949
# AICc:                                                               257.283
# BIC:                                                               2331.075
# R2:                                                                   0.669
# Adj. R2:                                                              0.649
#
# Variable                              Est.         SE  t(Est/SE)    p-value
# ------------------------------- ---------- ---------- ---------- ----------
# X0                                   5.642      7.080      0.797      0.425
# X1                                  -0.188      0.141     -1.335      0.182
# X2                                  -1.888      0.279     -6.763      0.000
#
# Geographically Weighted Regression (GWR) Results
# ---------------------------------------------------------------------------
# Spatial kernel:                                           Adaptive bisquare
# Bandwidth used:                                                      35.000
#
# Diagnostic information
# ---------------------------------------------------------------------------
# Residual sum of squares:                                           2024.894
# Effective number of parameters (trace(S)):                            5.020
# Degree of freedom (n - trace(S)):                                    29.980
# Sigma estimate:                                                       8.218
# Log-likelihood:                                                    -120.677
# AIC:                                                                253.392
# AICc:                                                               256.413
# BIC:                                                                262.755
# R2:                                                                   0.726
# Adjusted R2:                                                          0.679
# Adj. alpha (95%):                                                     0.030
# Adj. critical t value (95%):                                          2.267
#
# Summary Statistics For GWR Parameter Estimates
# ---------------------------------------------------------------------------
# Variable                   Mean        STD        Min     Median        Max
# -------------------- ---------- ---------- ---------- ---------- ----------
# X0                       10.366      8.172     -2.645     11.024     22.506
# X1                       -0.245      0.139     -0.432     -0.277     -0.005
# X2                       -1.971      0.113     -2.163     -1.981     -1.722
# ===========================================================================
#
# Mean R2 = 0.7260518481982874
# AIC = 253.39248308955584
# AICc = 256.4129447551629

# %%
altReg('other_data\polygons_points\Schools_with_Data\elem_fin_dis.shp', 'POINT_X', 
              'POINT_Y', 35, 'math', 'overall', '2015', target, 0.3, 'gwrresults/alt/elem_dis', 5)
# Out:
# ===========================================================================
# Model type                                                         Gaussian
# Number of observations:                                                  35
# Number of covariates:                                                     3
#
# Global Regression Results
# ---------------------------------------------------------------------------
# Residual sum of squares:                                           2565.277
# Log-likelihood:                                                    -124.816
# AIC:                                                                255.632
# AICc:                                                               258.966
# BIC:                                                               2451.506
# R2:                                                                   0.669
# Adj. R2:                                                              0.648
#
# Variable                              Est.         SE  t(Est/SE)    p-value
# ------------------------------- ---------- ---------- ---------- ----------
# X0                                   5.776      7.252      0.797      0.426
# X1                                  -0.164      0.144     -1.137      0.255
# X2                                  -1.963      0.286     -6.863      0.000
#
# Geographically Weighted Regression (GWR) Results
# ---------------------------------------------------------------------------
# Spatial kernel:                                           Adaptive bisquare
# Bandwidth used:                                                      35.000
#
# Diagnostic information
# ---------------------------------------------------------------------------
# Residual sum of squares:                                           2309.795
# Effective number of parameters (trace(S)):                            5.020
# Degree of freedom (n - trace(S)):                                    29.980
# Sigma estimate:                                                       8.777
# Log-likelihood:                                                    -122.980
# AIC:                                                                258.000
# AICc:                                                               261.020
# BIC:                                                                267.363
# R2:                                                                   0.702
# Adjusted R2:                                                          0.650
# Adj. alpha (95%):                                                     0.030
# Adj. critical t value (95%):                                          2.267
#
# Summary Statistics For GWR Parameter Estimates
# ---------------------------------------------------------------------------
# Variable                   Mean        STD        Min     Median        Max
# -------------------- ---------- ---------- ---------- ---------- ----------
# X0                        8.043      5.746     -0.464      7.477     17.556
# X1                       -0.194      0.111     -0.350     -0.218     -0.012
# X2                       -2.010      0.083     -2.137     -2.025     -1.800
# ===========================================================================
#
# Mean R2 = 0.7018445524191324
# AIC = 257.9999417755035
# AICc = 261.0204034411106

# %%
altReg('other_data\polygons_points\Schools_with_Data\mid_fin_dis.shp', 'POINT_X', 
              'POINT_Y', 10, 'read', 'overall', '2014', target, 0.3, 'gwrresults/alt/mid_dis', 5)
# Out:
# ===========================================================================
# Model type                                                         Gaussian
# Number of observations:                                                  10
# Number of covariates:                                                     3
#
# Global Regression Results
# ---------------------------------------------------------------------------
# Residual sum of squares:                                            241.875
# Log-likelihood:                                                     -30.119
# AIC:                                                                 66.237
# AICc:                                                                76.237
# BIC:                                                                225.757
# R2:                                                                   0.795
# Adj. R2:                                                              0.736
#
# Variable                              Est.         SE  t(Est/SE)    p-value
# ------------------------------- ---------- ---------- ---------- ----------
# X0                                  -4.405      8.149     -0.541      0.589
# X1                                   0.217      0.240      0.903      0.366
# X2                                  -1.728      0.410     -4.210      0.000
#
# Geographically Weighted Regression (GWR) Results
# ---------------------------------------------------------------------------
# Spatial kernel:                                           Adaptive bisquare
# Bandwidth used:                                                      10.000
#
# Diagnostic information
# ---------------------------------------------------------------------------
# Residual sum of squares:                                             99.643
# Effective number of parameters (trace(S)):                            5.002
# Degree of freedom (n - trace(S)):                                     4.998
# Sigma estimate:                                                       4.465
# Log-likelihood:                                                     -25.684
# AIC:                                                                 63.374
# AICc:                                                                91.416
# BIC:                                                                 65.190
# R2:                                                                   0.916
# Adjusted R2:                                                          0.810
# Adj. alpha (95%):                                                     0.030
# Adj. critical t value (95%):                                          2.574
#
# Summary Statistics For GWR Parameter Estimates
# ---------------------------------------------------------------------------
# Variable                   Mean        STD        Min     Median        Max
# -------------------- ---------- ---------- ---------- ---------- ----------
# X0                        5.053      9.960    -13.156      7.663     15.592
# X1                        0.076      0.227     -0.201     -0.001      0.525
# X2                       -1.806      0.319     -2.157     -1.919     -1.174
# ===========================================================================
#
# Mean R2 = 0.915558014581638
# AIC = 63.37361287159509
# AICc = 91.41623738979767

# %%
altReg('other_data\polygons_points\Schools_with_Data\mid_fin_dis.shp', 'POINT_X', 
              'POINT_Y', 10, 'math', 'overall', '2014', target, 0.3, 'gwrresults/alt/mid_dis', 5)
# Out:
# ===========================================================================
# Model type                                                         Gaussian
# Number of observations:                                                  10
# Number of covariates:                                                     3
#
# Global Regression Results
# ---------------------------------------------------------------------------
# Residual sum of squares:                                            704.206
# Log-likelihood:                                                     -35.462
# AIC:                                                                 76.924
# AICc:                                                                86.924
# BIC:                                                                688.088
# R2:                                                                   0.603
# Adj. R2:                                                              0.489
#
# Variable                              Est.         SE  t(Est/SE)    p-value
# ------------------------------- ---------- ---------- ---------- ----------
# X0                                 -16.952     13.904     -1.219      0.223
# X1                                   0.344      0.410      0.840      0.401
# X2                                  -1.952      0.700     -2.788      0.005
#
# Geographically Weighted Regression (GWR) Results
# ---------------------------------------------------------------------------
# Spatial kernel:                                           Adaptive bisquare
# Bandwidth used:                                                      10.000
#
# Diagnostic information
# ---------------------------------------------------------------------------
# Residual sum of squares:                                            486.944
# Effective number of parameters (trace(S)):                            5.002
# Degree of freedom (n - trace(S)):                                     4.998
# Sigma estimate:                                                       9.871
# Log-likelihood:                                                     -33.617
# AIC:                                                                 79.239
# AICc:                                                               107.282
# BIC:                                                                 81.055
# R2:                                                                   0.725
# Adjusted R2:                                                          0.381
# Adj. alpha (95%):                                                     0.030
# Adj. critical t value (95%):                                          2.574
#
# Summary Statistics For GWR Parameter Estimates
# ---------------------------------------------------------------------------
# Variable                   Mean        STD        Min     Median        Max
# -------------------- ---------- ---------- ---------- ---------- ----------
# X0                       -6.858     11.338    -25.965     -4.765      8.834
# X1                        0.245      0.236     -0.058      0.165      0.678
# X2                       -2.133      0.488     -2.670     -2.353     -1.152
# ===========================================================================
#
# Mean R2 = 0.7251708363078155
# AIC = 79.23913646869472
# AICc = 107.2817609868973

# %%
altReg('other_data\polygons_points\Schools_with_Data\mid_fin_dis.shp', 'POINT_X', 
              'POINT_Y', 10, 'read', 'overall', '2015', target, 0.3, 'gwrresults/alt/mid_dis', 5)
# Out:
# ===========================================================================
# Model type                                                         Gaussian
# Number of observations:                                                  10
# Number of covariates:                                                     3
#
# Global Regression Results
# ---------------------------------------------------------------------------
# Residual sum of squares:                                            253.015
# Log-likelihood:                                                     -30.344
# AIC:                                                                 66.687
# AICc:                                                                76.687
# BIC:                                                                236.897
# R2:                                                                   0.808
# Adj. R2:                                                              0.753
#
# Variable                              Est.         SE  t(Est/SE)    p-value
# ------------------------------- ---------- ---------- ---------- ----------
# X0                                 -18.210      8.368     -2.176      0.030
# X1                                   0.243      0.247      0.984      0.325
# X2                                  -1.851      0.421     -4.401      0.000
#
# Geographically Weighted Regression (GWR) Results
# ---------------------------------------------------------------------------
# Spatial kernel:                                           Adaptive bisquare
# Bandwidth used:                                                      10.000
#
# Diagnostic information
# ---------------------------------------------------------------------------
# Residual sum of squares:                                            110.253
# Effective number of parameters (trace(S)):                            5.124
# Degree of freedom (n - trace(S)):                                     4.876
# Sigma estimate:                                                       4.755
# Log-likelihood:                                                     -26.190
# AIC:                                                                 64.628
# AICc:                                                                94.963
# BIC:                                                                 66.481
# R2:                                                                   0.916
# Adjusted R2:                                                          0.805
# Adj. alpha (95%):                                                     0.029
# Adj. critical t value (95%):                                          2.589
#
# Summary Statistics For GWR Parameter Estimates
# ---------------------------------------------------------------------------
# Variable                   Mean        STD        Min     Median        Max
# -------------------- ---------- ---------- ---------- ---------- ----------
# X0                      -10.101      8.473    -23.837     -7.297      1.482
# X1                        0.154      0.230     -0.208      0.177      0.483
# X2                       -2.012      0.249     -2.321     -2.074     -1.552
# ===========================================================================
#
# Mean R2 = 0.9162076151802934
# AIC = 64.6282779185007
# AICc = 94.96327612103923

# %%
altReg('other_data\polygons_points\Schools_with_Data\mid_fin_dis.shp', 'POINT_X', 
              'POINT_Y', 10, 'math', 'overall', '2015', target, 0.3, 'gwrresults/alt/mid_dis', 5)
# Out:
# ===========================================================================
# Model type                                                         Gaussian
# Number of observations:                                                  10
# Number of covariates:                                                     3
#
# Global Regression Results
# ---------------------------------------------------------------------------
# Residual sum of squares:                                            299.008
# Log-likelihood:                                                     -31.179
# AIC:                                                                 68.358
# AICc:                                                                78.358
# BIC:                                                                282.890
# R2:                                                                   0.739
# Adj. R2:                                                              0.664
#
# Variable                              Est.         SE  t(Est/SE)    p-value
# ------------------------------- ---------- ---------- ---------- ----------
# X0                                 -34.659      9.097     -3.810      0.000
# X1                                   0.401      0.268      1.494      0.135
# X2                                  -1.819      0.457     -3.977      0.000
#
# Geographically Weighted Regression (GWR) Results
# ---------------------------------------------------------------------------
# Spatial kernel:                                           Adaptive bisquare
# Bandwidth used:                                                      10.000
#
# Diagnostic information
# ---------------------------------------------------------------------------
# Residual sum of squares:                                             97.861
# Effective number of parameters (trace(S)):                            5.124
# Degree of freedom (n - trace(S)):                                     4.876
# Sigma estimate:                                                       4.480
# Log-likelihood:                                                     -25.594
# AIC:                                                                 63.436
# AICc:                                                                93.771
# BIC:                                                                 65.289
# R2:                                                                   0.914
# Adjusted R2:                                                          0.801
# Adj. alpha (95%):                                                     0.029
# Adj. critical t value (95%):                                          2.589
#
# Summary Statistics For GWR Parameter Estimates
# ---------------------------------------------------------------------------
# Variable                   Mean        STD        Min     Median        Max
# -------------------- ---------- ---------- ---------- ---------- ----------
# X0                      -22.918     11.388    -42.714    -19.005     -9.008
# X1                        0.266      0.228     -0.068      0.257      0.621
# X2                       -2.033      0.247     -2.420     -2.133     -1.562
# ===========================================================================
#
# Mean R2 = 0.9144230462517638
# AIC = 63.435978197232046
# AICc = 93.77097639977057

# %%
altReg('other_data\polygons_points\Schools_with_Data\mid_fin_dis.shp', 'POINT_X', 
              'POINT_Y', 10, 'math', 'overall', '2015', target, 0.3, 'gwrresults/alt/FIXTEST', 5)
# Out:
# ===========================================================================
# Model type                                                         Gaussian
# Number of observations:                                                  10
# Number of covariates:                                                     3
#
# Global Regression Results
# ---------------------------------------------------------------------------
# Residual sum of squares:                                            348.600
# Log-likelihood:                                                     -31.946
# AIC:                                                                 69.892
# AICc:                                                                79.892
# BIC:                                                                332.482
# R2:                                                                   0.695
# Adj. R2:                                                              0.608
#
# Variable                              Est.         SE  t(Est/SE)    p-value
# ------------------------------- ---------- ---------- ---------- ----------
# X0                                 -27.827      9.932     -2.802      0.005
# X1                                   0.133      0.245      0.543      0.587
# X2                                  -1.797      0.507     -3.546      0.000
#
# Geographically Weighted Regression (GWR) Results
# ---------------------------------------------------------------------------
# Spatial kernel:                                           Adaptive bisquare
# Bandwidth used:                                                      10.000
#
# Diagnostic information
# ---------------------------------------------------------------------------
# Residual sum of squares:                                            122.180
# Effective number of parameters (trace(S)):                            5.180
# Degree of freedom (n - trace(S)):                                     4.820
# Sigma estimate:                                                       5.035
# Log-likelihood:                                                     -26.704
# AIC:                                                                 65.768
# AICc:                                                                97.243
# BIC:                                                                 67.638
# R2:                                                                   0.893
# Adjusted R2:                                                          0.748
# Adj. alpha (95%):                                                     0.029
# Adj. critical t value (95%):                                          2.595
#
# Summary Statistics For GWR Parameter Estimates
# ---------------------------------------------------------------------------
# Variable                   Mean        STD        Min     Median        Max
# -------------------- ---------- ---------- ---------- ---------- ----------
# X0                      -17.471     10.374    -33.816    -13.767     -3.298
# X1                        0.003      0.245     -0.397      0.082      0.305
# X2                       -1.960      0.447     -2.764     -1.990     -1.213
# ===========================================================================
#
# Mean R2 = 0.8931560773705591
# AIC = 65.76839554446059
# AICc = 97.24322738459989
