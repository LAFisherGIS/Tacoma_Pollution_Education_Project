# %%
#The purpose of this file is to convert the multiplied values accumulated by each school into mean levels
#I absolutely should have written a function to do this, and ultimately it was what drove me to automate field names
#in the GWR and OLS based tools, but at the time I hadn't thought of the precise method to use for that.
import geopandas as gpd

elemschl = gpd.read_file('E:/NONGIT Project_Resources/other_data/polygons_points/Schools_with_Data/elem_14_15.shp')


elemschl['OverPol14'] = elemschl['Sum_eOpol_'] / elemschl['Sum_eO_14']
elemschl['OverInc14'] = elemschl['Sum_eOinc_'] / elemschl['Sum_eO_14']
elemschl['OverPop14'] = elemschl['Sum_eOpop_'] / elemschl['Sum_eO_14']
elemschl['OverSch14'] = elemschl['Sum_eOedu_'] / elemschl['Sum_eO_14']
elemschl['OverBus14'] = elemschl['Sum_eObus_'] / elemschl['Sum_eO_14']
elemschl['OverSci14'] = elemschl['Sum_eOsci_'] / elemschl['Sum_eO_14']
elemschl['OverEdl14'] = elemschl['Sum_eOedl_'] / elemschl['Sum_eO_14']
elemschl['OverHea14'] = elemschl['Sum_eOheal'] / elemschl['Sum_eO_14']
elemschl['OverSer14'] = elemschl['Sum_eOserv'] / elemschl['Sum_eO_14']
elemschl['OverSal14'] = elemschl['Sum_eOsale'] / elemschl['Sum_eO_14']
elemschl['OverExt14'] = elemschl['Sum_eOextr'] / elemschl['Sum_eO_14']
elemschl['OverLog14'] = elemschl['Sum_eOlogi'] / elemschl['Sum_eO_14']

elemschl['WhitePol14'] = elemschl['Sum_eWpol_'] / elemschl['Sum_eW_14']
elemschl['WhiteInc14'] = elemschl['Sum_eWinc_'] / elemschl['Sum_eW_14']
elemschl['WhitePop14'] = elemschl['Sum_eWpop_'] / elemschl['Sum_eW_14']
elemschl['WhiteSch14'] = elemschl['Sum_eWedu_'] / elemschl['Sum_eW_14']
elemschl['WhiteBus14'] = elemschl['Sum_eWbus_'] / elemschl['Sum_eW_14']
elemschl['WhiteSci14'] = elemschl['Sum_eWsci_'] / elemschl['Sum_eW_14']
elemschl['WhiteEdl14'] = elemschl['Sum_eWedl_'] / elemschl['Sum_eW_14']
elemschl['WhiteHea14'] = elemschl['Sum_eWheal'] / elemschl['Sum_eW_14']
elemschl['WhiteSer14'] = elemschl['Sum_eWserv'] / elemschl['Sum_eW_14']
elemschl['WhiteSal14'] = elemschl['Sum_eWsale'] / elemschl['Sum_eW_14']
elemschl['WhiteExt14'] = elemschl['Sum_eWextr'] / elemschl['Sum_eW_14']
elemschl['WhiteLog14'] = elemschl['Sum_eWlogi'] / elemschl['Sum_eW_14']

elemschl['BlackPol14'] = elemschl['Sum_eBpol_'] / elemschl['Sum_eB_14']
elemschl['BlackInc14'] = elemschl['Sum_eBinc_'] / elemschl['Sum_eB_14']
elemschl['BlackPop14'] = elemschl['Sum_eBpop_'] / elemschl['Sum_eB_14']
elemschl['BlackSch14'] = elemschl['Sum_eBedu_'] / elemschl['Sum_eB_14']
elemschl['BlackBus14'] = elemschl['Sum_eBbus_'] / elemschl['Sum_eB_14']
elemschl['BlackSci14'] = elemschl['Sum_eBsci_'] / elemschl['Sum_eB_14']
elemschl['BlackEdl14'] = elemschl['Sum_eBedl_'] / elemschl['Sum_eB_14']
elemschl['BlackHea14'] = elemschl['Sum_eBheal'] / elemschl['Sum_eB_14']
elemschl['BlackSer14'] = elemschl['Sum_eBserv'] / elemschl['Sum_eB_14']
elemschl['BlackSal14'] = elemschl['Sum_eBsale'] / elemschl['Sum_eB_14']
elemschl['BlackExt14'] = elemschl['Sum_eBextr'] / elemschl['Sum_eB_14']
elemschl['BlackLog14'] = elemschl['Sum_eBlogi'] / elemschl['Sum_eB_14']

elemschl['NativPol14'] = elemschl['Sum_eNpol_'] / elemschl['Sum_eN_14']
elemschl['NativInc14'] = elemschl['Sum_eNinc_'] / elemschl['Sum_eN_14']
elemschl['NativPop14'] = elemschl['Sum_eNpop_'] / elemschl['Sum_eN_14']
elemschl['NativSch14'] = elemschl['Sum_eNedu_'] / elemschl['Sum_eN_14']
elemschl['NativBus14'] = elemschl['Sum_eNbus_'] / elemschl['Sum_eN_14']
elemschl['NativSci14'] = elemschl['Sum_eNsci_'] / elemschl['Sum_eN_14']
elemschl['NativEdl14'] = elemschl['Sum_eNedl_'] / elemschl['Sum_eN_14']
elemschl['NativHea14'] = elemschl['Sum_eNheal'] / elemschl['Sum_eN_14']
elemschl['NativSer14'] = elemschl['Sum_eNserv'] / elemschl['Sum_eN_14']
elemschl['NativSal14'] = elemschl['Sum_eNsale'] / elemschl['Sum_eN_14']
elemschl['NativExt14'] = elemschl['Sum_eNextr'] / elemschl['Sum_eN_14']
elemschl['NativLog14'] = elemschl['Sum_eNlogi'] / elemschl['Sum_eN_14']

elemschl['AsianPol14'] = elemschl['Sum_eApol_'] / elemschl['Sum_eA_14']
elemschl['AsianInc14'] = elemschl['Sum_eAinc_'] / elemschl['Sum_eA_14']
elemschl['AsianPop14'] = elemschl['Sum_eApop_'] / elemschl['Sum_eA_14']
elemschl['AsianSch14'] = elemschl['Sum_eAedu_'] / elemschl['Sum_eA_14']
elemschl['AsianBus14'] = elemschl['Sum_eAbus_'] / elemschl['Sum_eA_14']
elemschl['AsianSci14'] = elemschl['Sum_eAsci_'] / elemschl['Sum_eA_14']
elemschl['AsianEdl14'] = elemschl['Sum_eAedl_'] / elemschl['Sum_eA_14']
elemschl['AsianHea14'] = elemschl['Sum_eAheal'] / elemschl['Sum_eA_14']
elemschl['AsianSer14'] = elemschl['Sum_eAserv'] / elemschl['Sum_eA_14']
elemschl['AsianSal14'] = elemschl['Sum_eAsale'] / elemschl['Sum_eA_14']
elemschl['AsianExt14'] = elemschl['Sum_eAextr'] / elemschl['Sum_eA_14']
elemschl['AsianLog14'] = elemschl['Sum_eAlogi'] / elemschl['Sum_eA_14']

elemschl['PacifPol14'] = elemschl['Sum_ePpol_'] / elemschl['Sum_eP_14']
elemschl['PacifInc14'] = elemschl['Sum_ePinc_'] / elemschl['Sum_eP_14']
elemschl['PacifPop14'] = elemschl['Sum_ePpop_'] / elemschl['Sum_eP_14']
elemschl['PacifSch14'] = elemschl['Sum_ePedu_'] / elemschl['Sum_eP_14']
elemschl['PacifBus14'] = elemschl['Sum_ePbus_'] / elemschl['Sum_eP_14']
elemschl['PacifSci14'] = elemschl['Sum_ePsci_'] / elemschl['Sum_eP_14']
elemschl['PacifEdl14'] = elemschl['Sum_ePedl_'] / elemschl['Sum_eP_14']
elemschl['PacifHea14'] = elemschl['Sum_ePheal'] / elemschl['Sum_eP_14']
elemschl['PacifSer14'] = elemschl['Sum_ePserv'] / elemschl['Sum_eP_14']
elemschl['PacifSal14'] = elemschl['Sum_ePsale'] / elemschl['Sum_eP_14']
elemschl['PacifExt14'] = elemschl['Sum_ePextr'] / elemschl['Sum_eP_14']
elemschl['PacifLog14'] = elemschl['Sum_ePlogi'] / elemschl['Sum_eP_14']

elemschl['MultiPol14'] = elemschl['Sum_eMpol_'] / elemschl['Sum_eM_14']
elemschl['MultiInc14'] = elemschl['Sum_eMinc_'] / elemschl['Sum_eM_14']
elemschl['MultiPop14'] = elemschl['Sum_eMpop_'] / elemschl['Sum_eM_14']
elemschl['MultiSch14'] = elemschl['Sum_eMedu_'] / elemschl['Sum_eM_14']
elemschl['MultiBus14'] = elemschl['Sum_eMbus_'] / elemschl['Sum_eM_14']
elemschl['MultiSci14'] = elemschl['Sum_eMsci_'] / elemschl['Sum_eM_14']
elemschl['MultiEdl14'] = elemschl['Sum_eMedl_'] / elemschl['Sum_eM_14']
elemschl['MultiHea14'] = elemschl['Sum_eMheal'] / elemschl['Sum_eM_14']
elemschl['MultiSer14'] = elemschl['Sum_eMserv'] / elemschl['Sum_eM_14']
elemschl['MultiSal14'] = elemschl['Sum_eMsale'] / elemschl['Sum_eM_14']
elemschl['MultiExt14'] = elemschl['Sum_eMextr'] / elemschl['Sum_eM_14']
elemschl['MultiLog14'] = elemschl['Sum_eMlogi'] / elemschl['Sum_eM_14']

elemschl['OverPol15'] = elemschl['Sum_eOpo_1'] / elemschl['Sum_eO_15']
elemschl['OverInc15'] = elemschl['Sum_eOin_1'] / elemschl['Sum_eO_15']
elemschl['OverPop15'] = elemschl['Sum_eOpo_2'] / elemschl['Sum_eO_15']
elemschl['OverSch15'] = elemschl['Sum_eOed_1'] / elemschl['Sum_eO_15']
elemschl['OverBus15'] = elemschl['Sum_eObu_1'] / elemschl['Sum_eO_15']
elemschl['OverSci15'] = elemschl['Sum_eOsc_1'] / elemschl['Sum_eO_15']
elemschl['OverEdl15'] = elemschl['Sum_eOed_1'] / elemschl['Sum_eO_15']
elemschl['OverHea15'] = elemschl['Sum_eOhe_1'] / elemschl['Sum_eO_15']
elemschl['OverSer15'] = elemschl['Sum_eOse_1'] / elemschl['Sum_eO_15']
elemschl['OverSal15'] = elemschl['Sum_eOsa_1'] / elemschl['Sum_eO_15']
elemschl['OverExt15'] = elemschl['Sum_eOex_1'] / elemschl['Sum_eO_15']
elemschl['OverLog15'] = elemschl['Sum_eOlo_1'] / elemschl['Sum_eO_15']

elemschl['WhitePol15'] = elemschl['Sum_eWpo_1'] / elemschl['Sum_eW_15']
elemschl['WhiteInc15'] = elemschl['Sum_eWin_1'] / elemschl['Sum_eW_15']
elemschl['WhitePop15'] = elemschl['Sum_eWpo_2'] / elemschl['Sum_eW_15']
elemschl['WhiteSch15'] = elemschl['Sum_eWed_1'] / elemschl['Sum_eW_15']
elemschl['WhiteBus15'] = elemschl['Sum_eWbu_1'] / elemschl['Sum_eW_15']
elemschl['WhiteSci15'] = elemschl['Sum_eWsc_1'] / elemschl['Sum_eW_15']
elemschl['WhiteEdl15'] = elemschl['Sum_eWed_1'] / elemschl['Sum_eW_15']
elemschl['WhiteHea15'] = elemschl['Sum_eWhe_1'] / elemschl['Sum_eW_15']
elemschl['WhiteSer15'] = elemschl['Sum_eWse_1'] / elemschl['Sum_eW_15']
elemschl['WhiteSal15'] = elemschl['Sum_eWsa_1'] / elemschl['Sum_eW_15']
elemschl['WhiteExt15'] = elemschl['Sum_eWex_1'] / elemschl['Sum_eW_15']
elemschl['WhiteLog15'] = elemschl['Sum_eWlo_1'] / elemschl['Sum_eW_15']

elemschl['BlackPol15'] = elemschl['Sum_eBpo_1'] / elemschl['Sum_eB_15']
elemschl['BlackInc15'] = elemschl['Sum_eBin_1'] / elemschl['Sum_eB_15']
elemschl['BlackPop15'] = elemschl['Sum_eBpo_2'] / elemschl['Sum_eB_15']
elemschl['BlackSch15'] = elemschl['Sum_eBed_1'] / elemschl['Sum_eB_15']
elemschl['BlackBus15'] = elemschl['Sum_eBbu_1'] / elemschl['Sum_eB_15']
elemschl['BlackSci15'] = elemschl['Sum_eBsc_1'] / elemschl['Sum_eB_15']
elemschl['BlackEdl15'] = elemschl['Sum_eBed_1'] / elemschl['Sum_eB_15']
elemschl['BlackHea15'] = elemschl['Sum_eBhe_1'] / elemschl['Sum_eB_15']
elemschl['BlackSer15'] = elemschl['Sum_eBse_1'] / elemschl['Sum_eB_15']
elemschl['BlackSal15'] = elemschl['Sum_eBsa_1'] / elemschl['Sum_eB_15']
elemschl['BlackExt15'] = elemschl['Sum_eBex_1'] / elemschl['Sum_eB_15']
elemschl['BlackLog15'] = elemschl['Sum_eBlo_1'] / elemschl['Sum_eB_15']

elemschl['NativPol15'] = elemschl['Sum_eNpo_1'] / elemschl['Sum_eN_15']
elemschl['NativInc15'] = elemschl['Sum_eNin_1'] / elemschl['Sum_eN_15']
elemschl['NativPop15'] = elemschl['Sum_eNpo_2'] / elemschl['Sum_eN_15']
elemschl['NativSch15'] = elemschl['Sum_eNed_1'] / elemschl['Sum_eN_15']
elemschl['NativBus15'] = elemschl['Sum_eNbu_1'] / elemschl['Sum_eN_15']
elemschl['NativSci15'] = elemschl['Sum_eNsc_1'] / elemschl['Sum_eN_15']
elemschl['NativEdl15'] = elemschl['Sum_eNed_1'] / elemschl['Sum_eN_15']
elemschl['NativHea15'] = elemschl['Sum_eNhe_1'] / elemschl['Sum_eN_15']
elemschl['NativSer15'] = elemschl['Sum_eNse_1'] / elemschl['Sum_eN_15']
elemschl['NativSal15'] = elemschl['Sum_eNsa_1'] / elemschl['Sum_eN_15']
elemschl['NativExt15'] = elemschl['Sum_eNex_1'] / elemschl['Sum_eN_15']
elemschl['NativLog15'] = elemschl['Sum_eNlo_1'] / elemschl['Sum_eN_15']

elemschl['AsianPol15'] = elemschl['Sum_eApo_1'] / elemschl['Sum_eA_15']
elemschl['AsianInc15'] = elemschl['Sum_eAin_1'] / elemschl['Sum_eA_15']
elemschl['AsianPop15'] = elemschl['Sum_eApo_2'] / elemschl['Sum_eA_15']
elemschl['AsianSch15'] = elemschl['Sum_eAed_1'] / elemschl['Sum_eA_15']
elemschl['AsianBus15'] = elemschl['Sum_eAbu_1'] / elemschl['Sum_eA_15']
elemschl['AsianSci15'] = elemschl['Sum_eAsc_1'] / elemschl['Sum_eA_15']
elemschl['AsianEdl15'] = elemschl['Sum_eAed_1'] / elemschl['Sum_eA_15']
elemschl['AsianHea15'] = elemschl['Sum_eAhe_1'] / elemschl['Sum_eA_15']
elemschl['AsianSer15'] = elemschl['Sum_eAse_1'] / elemschl['Sum_eA_15']
elemschl['AsianSal15'] = elemschl['Sum_eAsa_1'] / elemschl['Sum_eA_15']
elemschl['AsianExt15'] = elemschl['Sum_eAex_1'] / elemschl['Sum_eA_15']
elemschl['AsianLog15'] = elemschl['Sum_eAlo_1'] / elemschl['Sum_eA_15']

elemschl['PacifPol15'] = elemschl['Sum_ePpo_1'] / elemschl['Sum_eP_15']
elemschl['PacifInc15'] = elemschl['Sum_ePin_1'] / elemschl['Sum_eP_15']
elemschl['PacifPop15'] = elemschl['Sum_ePpo_2'] / elemschl['Sum_eP_15']
elemschl['PacifSch15'] = elemschl['Sum_ePed_1'] / elemschl['Sum_eP_15']
elemschl['PacifBus15'] = elemschl['Sum_ePbu_1'] / elemschl['Sum_eP_15']
elemschl['PacifSci15'] = elemschl['Sum_ePsc_1'] / elemschl['Sum_eP_15']
elemschl['PacifEdl15'] = elemschl['Sum_ePed_1'] / elemschl['Sum_eP_15']
elemschl['PacifHea15'] = elemschl['Sum_ePhe_1'] / elemschl['Sum_eP_15']
elemschl['PacifSer15'] = elemschl['Sum_ePse_1'] / elemschl['Sum_eP_15']
elemschl['PacifSal15'] = elemschl['Sum_ePsa_1'] / elemschl['Sum_eP_15']
elemschl['PacifExt15'] = elemschl['Sum_ePex_1'] / elemschl['Sum_eP_15']
elemschl['PacifLog15'] = elemschl['Sum_ePlo_1'] / elemschl['Sum_eP_15']

elemschl['MultiPol15'] = elemschl['Sum_eMpo_1'] / elemschl['Sum_eM_15']
elemschl['MultiInc15'] = elemschl['Sum_eMin_1'] / elemschl['Sum_eM_15']
elemschl['MultiPop15'] = elemschl['Sum_eMpo_2'] / elemschl['Sum_eM_15']
elemschl['MultiSch15'] = elemschl['Sum_eMed_1'] / elemschl['Sum_eM_15']
elemschl['MultiBus15'] = elemschl['Sum_eMbu_1'] / elemschl['Sum_eM_15']
elemschl['MultiSci15'] = elemschl['Sum_eMsc_1'] / elemschl['Sum_eM_15']
elemschl['MultiEdl15'] = elemschl['Sum_eMed_1'] / elemschl['Sum_eM_15']
elemschl['MultiHea15'] = elemschl['Sum_eMhe_1'] / elemschl['Sum_eM_15']
elemschl['MultiSer15'] = elemschl['Sum_eMse_1'] / elemschl['Sum_eM_15']
elemschl['MultiSal15'] = elemschl['Sum_eMsa_1'] / elemschl['Sum_eM_15']
elemschl['MultiExt15'] = elemschl['Sum_eMex_1'] / elemschl['Sum_eM_15']
elemschl['MultiLog15'] = elemschl['Sum_eMlo_1'] / elemschl['Sum_eM_15']

elemschl.to_csv('E:/NONGIT Project_Resources/other_data/polygons_points/Schools_with_Data/elem_avg_w_junk.csv')
# Out:
# C:\Users\PlotVitalNPC\anaconda3\envs\springwork1\lib\site-packages\ipykernel_launcher.py:110: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
# C:\Users\PlotVitalNPC\anaconda3\envs\springwork1\lib\site-packages\ipykernel_launcher.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
# ...

# %%
import geopandas as gpd

midschl = gpd.read_file('E:/NONGIT Project_Resources/other_data/polygons_points/Schools_with_Data/mid_14_15.shp')

midschl['OverPol14'] = midschl['Sum_mOpol_'] / midschl['Sum_mO_14']
midschl['OverInc14'] = midschl['Sum_mOinc_'] / midschl['Sum_mO_14']
midschl['OverPop14'] = midschl['Sum_mOpop_'] / midschl['Sum_mO_14']
midschl['OverSch14'] = midschl['Sum_mOedu_'] / midschl['Sum_mO_14']
midschl['OverBus14'] = midschl['Sum_mObus_'] / midschl['Sum_mO_14']
midschl['OverSci14'] = midschl['Sum_mOsci_'] / midschl['Sum_mO_14']
midschl['OverEdl14'] = midschl['Sum_mOedl_'] / midschl['Sum_mO_14']
midschl['OverHea14'] = midschl['Sum_mOheal'] / midschl['Sum_mO_14']
midschl['OverSer14'] = midschl['Sum_mOserv'] / midschl['Sum_mO_14']
midschl['OverSal14'] = midschl['Sum_mOsale'] / midschl['Sum_mO_14']
midschl['OverExt14'] = midschl['Sum_mOextr'] / midschl['Sum_mO_14']
midschl['OverLog14'] = midschl['Sum_mOlogi'] / midschl['Sum_mO_14']

midschl['WhitePol14'] = midschl['Sum_mWpol_'] / midschl['Sum_mW_14']
midschl['WhiteInc14'] = midschl['Sum_mWinc_'] / midschl['Sum_mW_14']
midschl['WhitePop14'] = midschl['Sum_mWpop_'] / midschl['Sum_mW_14']
midschl['WhiteSch14'] = midschl['Sum_mWedu_'] / midschl['Sum_mW_14']
midschl['WhiteBus14'] = midschl['Sum_mWbus_'] / midschl['Sum_mW_14']
midschl['WhiteSci14'] = midschl['Sum_mWsci_'] / midschl['Sum_mW_14']
midschl['WhiteEdl14'] = midschl['Sum_mWedl_'] / midschl['Sum_mW_14']
midschl['WhiteHea14'] = midschl['Sum_mWheal'] / midschl['Sum_mW_14']
midschl['WhiteSer14'] = midschl['Sum_mWserv'] / midschl['Sum_mW_14']
midschl['WhiteSal14'] = midschl['Sum_mWsale'] / midschl['Sum_mW_14']
midschl['WhiteExt14'] = midschl['Sum_mWextr'] / midschl['Sum_mW_14']
midschl['WhiteLog14'] = midschl['Sum_mWlogi'] / midschl['Sum_mW_14']

midschl['BlackPol14'] = midschl['Sum_mBpol_'] / midschl['Sum_mB_14']
midschl['BlackInc14'] = midschl['Sum_mBinc_'] / midschl['Sum_mB_14']
midschl['BlackPop14'] = midschl['Sum_mBpop_'] / midschl['Sum_mB_14']
midschl['BlackSch14'] = midschl['Sum_mBedu_'] / midschl['Sum_mB_14']
midschl['BlackBus14'] = midschl['Sum_mBbus_'] / midschl['Sum_mB_14']
midschl['BlackSci14'] = midschl['Sum_mBsci_'] / midschl['Sum_mB_14']
midschl['BlackEdl14'] = midschl['Sum_mBedl_'] / midschl['Sum_mB_14']
midschl['BlackHea14'] = midschl['Sum_mBheal'] / midschl['Sum_mB_14']
midschl['BlackSer14'] = midschl['Sum_mBserv'] / midschl['Sum_mB_14']
midschl['BlackSal14'] = midschl['Sum_mBsale'] / midschl['Sum_mB_14']
midschl['BlackExt14'] = midschl['Sum_mBextr'] / midschl['Sum_mB_14']
midschl['BlackLog14'] = midschl['Sum_mBlogi'] / midschl['Sum_mB_14']

midschl['NativPol14'] = midschl['Sum_mNpol_'] / midschl['Sum_mN_14']
midschl['NativInc14'] = midschl['Sum_mNinc_'] / midschl['Sum_mN_14']
midschl['NativPop14'] = midschl['Sum_mNpop_'] / midschl['Sum_mN_14']
midschl['NativSch14'] = midschl['Sum_mNedu_'] / midschl['Sum_mN_14']
midschl['NativBus14'] = midschl['Sum_mNbus_'] / midschl['Sum_mN_14']
midschl['NativSci14'] = midschl['Sum_mNsci_'] / midschl['Sum_mN_14']
midschl['NativEdl14'] = midschl['Sum_mNedl_'] / midschl['Sum_mN_14']
midschl['NativHea14'] = midschl['Sum_mNheal'] / midschl['Sum_mN_14']
midschl['NativSer14'] = midschl['Sum_mNserv'] / midschl['Sum_mN_14']
midschl['NativSal14'] = midschl['Sum_mNsale'] / midschl['Sum_mN_14']
midschl['NativExt14'] = midschl['Sum_mNextr'] / midschl['Sum_mN_14']
midschl['NativLog14'] = midschl['Sum_mNlogi'] / midschl['Sum_mN_14']

midschl['AsianPol14'] = midschl['Sum_eApol_'] / midschl['Sum_eA_14']
midschl['AsianInc14'] = midschl['Sum_eAinc_'] / midschl['Sum_eA_14']
midschl['AsianPop14'] = midschl['Sum_eApop_'] / midschl['Sum_eA_14']
midschl['AsianSch14'] = midschl['Sum_eAedu_'] / midschl['Sum_eA_14']
midschl['AsianBus14'] = midschl['Sum_eAbus_'] / midschl['Sum_eA_14']
midschl['AsianSci14'] = midschl['Sum_eAsci_'] / midschl['Sum_eA_14']
midschl['AsianEdl14'] = midschl['Sum_eAedl_'] / midschl['Sum_eA_14']
midschl['AsianHea14'] = midschl['Sum_eAheal'] / midschl['Sum_eA_14']
midschl['AsianSer14'] = midschl['Sum_eAserv'] / midschl['Sum_eA_14']
midschl['AsianSal14'] = midschl['Sum_eAsale'] / midschl['Sum_eA_14']
midschl['AsianExt14'] = midschl['Sum_eAextr'] / midschl['Sum_eA_14']
midschl['AsianLog14'] = midschl['Sum_eAlogi'] / midschl['Sum_eA_14']

midschl['PacifPol14'] = midschl['Sum_mPpol_'] / midschl['Sum_mP_14']
midschl['PacifInc14'] = midschl['Sum_mPinc_'] / midschl['Sum_mP_14']
midschl['PacifPop14'] = midschl['Sum_mPpop_'] / midschl['Sum_mP_14']
midschl['PacifSch14'] = midschl['Sum_mPedu_'] / midschl['Sum_mP_14']
midschl['PacifBus14'] = midschl['Sum_mPbus_'] / midschl['Sum_mP_14']
midschl['PacifSci14'] = midschl['Sum_mPsci_'] / midschl['Sum_mP_14']
midschl['PacifEdl14'] = midschl['Sum_mPedl_'] / midschl['Sum_mP_14']
midschl['PacifHea14'] = midschl['Sum_mPheal'] / midschl['Sum_mP_14']
midschl['PacifSer14'] = midschl['Sum_mPserv'] / midschl['Sum_mP_14']
midschl['PacifSal14'] = midschl['Sum_mPsale'] / midschl['Sum_mP_14']
midschl['PacifExt14'] = midschl['Sum_mPextr'] / midschl['Sum_mP_14']
midschl['PacifLog14'] = midschl['Sum_mPlogi'] / midschl['Sum_mP_14']

midschl['MultiPol14'] = midschl['Sum_mMpol_'] / midschl['Sum_mM_14']
midschl['MultiInc14'] = midschl['Sum_mMinc_'] / midschl['Sum_mM_14']
midschl['MultiPop14'] = midschl['Sum_mMpop_'] / midschl['Sum_mM_14']
midschl['MultiSch14'] = midschl['Sum_mMedu_'] / midschl['Sum_mM_14']
midschl['MultiBus14'] = midschl['Sum_mMbus_'] / midschl['Sum_mM_14']
midschl['MultiSci14'] = midschl['Sum_mMsci_'] / midschl['Sum_mM_14']
midschl['MultiEdl14'] = midschl['Sum_mMedl_'] / midschl['Sum_mM_14']
midschl['MultiHea14'] = midschl['Sum_mMheal'] / midschl['Sum_mM_14']
midschl['MultiSer14'] = midschl['Sum_mMserv'] / midschl['Sum_mM_14']
midschl['MultiSal14'] = midschl['Sum_mMsale'] / midschl['Sum_mM_14']
midschl['MultiExt14'] = midschl['Sum_mMextr'] / midschl['Sum_mM_14']
midschl['MultiLog14'] = midschl['Sum_mMlogi'] / midschl['Sum_mM_14']

midschl['OverPol15'] = midschl['Sum_mOpo_1'] / midschl['Sum_mO_15']
midschl['OverInc15'] = midschl['Sum_mOin_1'] / midschl['Sum_mO_15']
midschl['OverPop15'] = midschl['Sum_mOpo_2'] / midschl['Sum_mO_15']
midschl['OverSch15'] = midschl['Sum_mOed_1'] / midschl['Sum_mO_15']
midschl['OverBus15'] = midschl['Sum_mObu_1'] / midschl['Sum_mO_15']
midschl['OverSci15'] = midschl['Sum_mOsc_1'] / midschl['Sum_mO_15']
midschl['OverEdl15'] = midschl['Sum_mOed_1'] / midschl['Sum_mO_15']
midschl['OverHea15'] = midschl['Sum_mOhe_1'] / midschl['Sum_mO_15']
midschl['OverSer15'] = midschl['Sum_mOse_1'] / midschl['Sum_mO_15']
midschl['OverSal15'] = midschl['Sum_mOsa_1'] / midschl['Sum_mO_15']
midschl['OverExt15'] = midschl['Sum_mOex_1'] / midschl['Sum_mO_15']
midschl['OverLog15'] = midschl['Sum_mOlo_1'] / midschl['Sum_mO_15']

midschl['WhitePol15'] = midschl['Sum_mWpo_1'] / midschl['Sum_mW_15']
midschl['WhiteInc15'] = midschl['Sum_mWin_1'] / midschl['Sum_mW_15']
midschl['WhitePop15'] = midschl['Sum_mWpo_2'] / midschl['Sum_mW_15']
midschl['WhiteSch15'] = midschl['Sum_mWed_1'] / midschl['Sum_mW_15']
midschl['WhiteBus15'] = midschl['Sum_mWbu_1'] / midschl['Sum_mW_15']
midschl['WhiteSci15'] = midschl['Sum_mWsc_1'] / midschl['Sum_mW_15']
midschl['WhiteEdl15'] = midschl['Sum_mWed_1'] / midschl['Sum_mW_15']
midschl['WhiteHea15'] = midschl['Sum_mWhe_1'] / midschl['Sum_mW_15']
midschl['WhiteSer15'] = midschl['Sum_mWse_1'] / midschl['Sum_mW_15']
midschl['WhiteSal15'] = midschl['Sum_mWsa_1'] / midschl['Sum_mW_15']
midschl['WhiteExt15'] = midschl['Sum_mWex_1'] / midschl['Sum_mW_15']
midschl['WhiteLog15'] = midschl['Sum_mWlo_1'] / midschl['Sum_mW_15']

midschl['BlackPol15'] = midschl['Sum_mBpo_1'] / midschl['Sum_mB_15']
midschl['BlackInc15'] = midschl['Sum_mBin_1'] / midschl['Sum_mB_15']
midschl['BlackPop15'] = midschl['Sum_mBpo_2'] / midschl['Sum_mB_15']
midschl['BlackSch15'] = midschl['Sum_mBed_1'] / midschl['Sum_mB_15']
midschl['BlackBus15'] = midschl['Sum_mBbu_1'] / midschl['Sum_mB_15']
midschl['BlackSci15'] = midschl['Sum_mBsc_1'] / midschl['Sum_mB_15']
midschl['BlackEdl15'] = midschl['Sum_mBed_1'] / midschl['Sum_mB_15']
midschl['BlackHea15'] = midschl['Sum_mBhe_1'] / midschl['Sum_mB_15']
midschl['BlackSer15'] = midschl['Sum_mBse_1'] / midschl['Sum_mB_15']
midschl['BlackSal15'] = midschl['Sum_mBsa_1'] / midschl['Sum_mB_15']
midschl['BlackExt15'] = midschl['Sum_mBex_1'] / midschl['Sum_mB_15']
midschl['BlackLog15'] = midschl['Sum_mBlo_1'] / midschl['Sum_mB_15']

midschl['NativPol15'] = midschl['Sum_mNpo_1'] / midschl['Sum_mN_15']
midschl['NativInc15'] = midschl['Sum_mNin_1'] / midschl['Sum_mN_15']
midschl['NativPop15'] = midschl['Sum_mNpo_2'] / midschl['Sum_mN_15']
midschl['NativSch15'] = midschl['Sum_mNed_1'] / midschl['Sum_mN_15']
midschl['NativBus15'] = midschl['Sum_mNbu_1'] / midschl['Sum_mN_15']
midschl['NativSci15'] = midschl['Sum_mNsc_1'] / midschl['Sum_mN_15']
midschl['NativEdl15'] = midschl['Sum_mNed_1'] / midschl['Sum_mN_15']
midschl['NativHea15'] = midschl['Sum_mNhe_1'] / midschl['Sum_mN_15']
midschl['NativSer15'] = midschl['Sum_mNse_1'] / midschl['Sum_mN_15']
midschl['NativSal15'] = midschl['Sum_mNsa_1'] / midschl['Sum_mN_15']
midschl['NativExt15'] = midschl['Sum_mNex_1'] / midschl['Sum_mN_15']
midschl['NativLog15'] = midschl['Sum_mNlo_1'] / midschl['Sum_mN_15']

midschl['AsianPol15'] = midschl['Sum_mApo_1'] / midschl['Sum_eA_15']
midschl['AsianInc15'] = midschl['Sum_mAin_1'] / midschl['Sum_eA_15']
midschl['AsianPop15'] = midschl['Sum_mApo_2'] / midschl['Sum_eA_15']
midschl['AsianSch15'] = midschl['Sum_mAed_1'] / midschl['Sum_eA_15']
midschl['AsianBus15'] = midschl['Sum_mAbu_1'] / midschl['Sum_eA_15']
midschl['AsianSci15'] = midschl['Sum_mAsc_1'] / midschl['Sum_eA_15']
midschl['AsianEdl15'] = midschl['Sum_mAed_1'] / midschl['Sum_eA_15']
midschl['AsianHea15'] = midschl['Sum_mAhe_1'] / midschl['Sum_eA_15']
midschl['AsianSer15'] = midschl['Sum_mAse_1'] / midschl['Sum_eA_15']
midschl['AsianSal15'] = midschl['Sum_mAsa_1'] / midschl['Sum_eA_15']
midschl['AsianExt15'] = midschl['Sum_mAex_1'] / midschl['Sum_eA_15']
midschl['AsianLog15'] = midschl['Sum_mAlo_1'] / midschl['Sum_eA_15']

midschl['PacifPol15'] = midschl['Sum_mPpo_1'] / midschl['Sum_mP_15']
midschl['PacifInc15'] = midschl['Sum_mPin_1'] / midschl['Sum_mP_15']
midschl['PacifPop15'] = midschl['Sum_mPpo_2'] / midschl['Sum_mP_15']
midschl['PacifSch15'] = midschl['Sum_mPed_1'] / midschl['Sum_mP_15']
midschl['PacifBus15'] = midschl['Sum_mPbu_1'] / midschl['Sum_mP_15']
midschl['PacifSci15'] = midschl['Sum_mPsc_1'] / midschl['Sum_mP_15']
midschl['PacifEdl15'] = midschl['Sum_mPed_1'] / midschl['Sum_mP_15']
midschl['PacifHea15'] = midschl['Sum_mPhe_1'] / midschl['Sum_mP_15']
midschl['PacifSer15'] = midschl['Sum_mPse_1'] / midschl['Sum_mP_15']
midschl['PacifSal15'] = midschl['Sum_mPsa_1'] / midschl['Sum_mP_15']
midschl['PacifExt15'] = midschl['Sum_mPex_1'] / midschl['Sum_mP_15']
midschl['PacifLog15'] = midschl['Sum_mPlo_1'] / midschl['Sum_mP_15']

midschl['MultiPol15'] = midschl['Sum_mMpo_1'] / midschl['Sum_mM_15']
midschl['MultiInc15'] = midschl['Sum_mMin_1'] / midschl['Sum_mM_15']
midschl['MultiPop15'] = midschl['Sum_mMpo_2'] / midschl['Sum_mM_15']
midschl['MultiSch15'] = midschl['Sum_mMed_1'] / midschl['Sum_mM_15']
midschl['MultiBus15'] = midschl['Sum_mMbu_1'] / midschl['Sum_mM_15']
midschl['MultiSci15'] = midschl['Sum_mMsc_1'] / midschl['Sum_mM_15']
midschl['MultiEdl15'] = midschl['Sum_mMed_1'] / midschl['Sum_mM_15']
midschl['MultiHea15'] = midschl['Sum_mMhe_1'] / midschl['Sum_mM_15']
midschl['MultiSer15'] = midschl['Sum_mMse_1'] / midschl['Sum_mM_15']
midschl['MultiSal15'] = midschl['Sum_mMsa_1'] / midschl['Sum_mM_15']
midschl['MultiExt15'] = midschl['Sum_mMex_1'] / midschl['Sum_mM_15']
midschl['MultiLog15'] = midschl['Sum_mMlo_1'] / midschl['Sum_mM_15']

midschl.to_csv('E:/NONGIT Project_Resources/other_data/polygons_points/Schools_with_Data/mid_avg_w_junk.csv')
# Out:
# C:\Users\PlotVitalNPC\anaconda3\envs\springwork1\lib\site-packages\ipykernel_launcher.py:109: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
# C:\Users\PlotVitalNPC\anaconda3\envs\springwork1\lib\site-packages\ipykernel_launcher.py:110: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
# ...
